# %% [markdown]
# # Tarefa 02
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os monitores
# - Divirta-se :)

# %% [markdown]
# #### 1. Carregue os dados da tarefa anterior

# %%
from pandas_datareader import data as pdr
import plotly.express as px
from plotly import graph_objects
import yfinance as yf
import datetime as dt
import pandas as pd
import numpy as np

ativos = ['PETR4.SA', 'ABEV3.SA', 'VALE3.SA']

yf_data = yf.download(ativos, start='2023-03-25', end='2024-03-25')
yf_data
# Out:
# [*********************100%%**********************]  3 of 3 completed
# Price       Adj Close                          Close                        \
# Ticker       ABEV3.SA   PETR4.SA   VALE3.SA ABEV3.SA   PETR4.SA   VALE3.SA
# Date
# 2023-03-27  13.238050  17.910372  72.258240    13.93  23.180000  78.540001
# 2023-03-28  13.865265  18.227163  73.021858    14.59  23.590000  79.370003
# 2023-03-29  14.074337  18.466690  74.070679    14.81  23.900000  80.510002
# 2023-03-30  14.083839  18.520775  75.275909    14.82  23.969999  81.820000
# 2023-03-31  13.618179  18.118990  73.868279    14.33  23.450001  80.290001
# ...               ...        ...        ...      ...        ...        ...
# 2024-03-18  12.630000  36.340000  60.900002    12.63  36.340000  60.900002
# 2024-03-19  12.540000  36.070000  61.400002    12.54  36.070000  61.400002
# 2024-03-20  12.540000  36.700001  61.810001    12.54  36.700001  61.810001
# ...

# %% [markdown]
# #### 2. Média móvel
#
# 1. Faça uma média móvel  em 90 dias dos valores de fechamento ajustados dos ativos que você escolheu
# 2. Utilizando a fução ```rolling()```, calcule o desvio pardão desses ativos ao longo do tempo, utilizando a mesma janela móvel do item acima
# 2. Monte um gráfico de linhas para as médias móveis dos ativos da sua base
# 4. Monte um gráfico de linhas para os desvios padrão em janela móvel
# 5. Compare os dois gráficos que você fez com o da tarefa anterior. Veja se eles apontam conclusões semelhantes quanto aos períodos de maior volatilidade (variação) dos ativos.

# %%
df = yf_data['Adj Close'].stack().reset_index()
df.columns = ['data', 'ativo', 'valor']
df
# Out:
#           data     ativo      valor
# 0   2023-03-27  ABEV3.SA  13.238050
# 1   2023-03-27  PETR4.SA  17.910372
# 2   2023-03-27  VALE3.SA  72.258240
# 3   2023-03-28  ABEV3.SA  13.865265
# 4   2023-03-28  PETR4.SA  18.227163
# ..         ...       ...        ...
# 736 2024-03-21  PETR4.SA  35.700001
# 737 2024-03-21  VALE3.SA  61.660000
# 738 2024-03-22  ABEV3.SA  12.410000
# 739 2024-03-22  PETR4.SA  36.049999
# 740 2024-03-22  VALE3.SA  60.950001
#
# [741 rows x 3 columns]

# %%
media_movel = df['valor'].rolling(90).mean()
fig = px.line(df, x="data", y=media_movel, color='ativo', template='plotly_white')
fig.show()
# Out:
# <div>                            <div id="b26e541c-7daf-4826-af1f-6993973ce6aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b26e541c-7daf-4826-af1f-6993973ce6aa")) {                    Plotly.newPlot(                        "b26e541c-7daf-4826-af1f-6993973ce6aa",                        [{"hovertemplate":"ativo=ABEV3.SA\u003cbr\u003edata=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ABEV3.SA","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ABEV3.SA","orientation":"v","showlegend":true,"x":["2023-03-27T00:00:00","2023-03-28T00:00:00","2023-03-29T00:00:00","2023-03-30T00:00:00","2023-03-31T00:00:00","2023-04-03T00:00:00","2023-04-04T00:00:00","2023-04-05T00:00:00","202
# ...

# %%
desvio_padrao = df['valor'].rolling(90).std()
fig = px.line(df, x="data", y=desvio_padrao, color='ativo', template='plotly_white')
fig.show()
# Out:
# <div>                            <div id="f43277c1-b54a-4340-a96b-57b9c9536bc6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f43277c1-b54a-4340-a96b-57b9c9536bc6")) {                    Plotly.newPlot(                        "f43277c1-b54a-4340-a96b-57b9c9536bc6",                        [{"hovertemplate":"ativo=ABEV3.SA\u003cbr\u003edata=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ABEV3.SA","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ABEV3.SA","orientation":"v","showlegend":true,"x":["2023-03-27T00:00:00","2023-03-28T00:00:00","2023-03-29T00:00:00","2023-03-30T00:00:00","2023-03-31T00:00:00","2023-04-03T00:00:00","2023-04-04T00:00:00","2023-04-05T00:00:00","202
# ...

# %% [markdown]
# O gráfico mostra uma variação bem menor comparado aquele do exercício passado, onde temos tanto na média móvel quanto no desvio padrão pouca diferença entre os ativos.

# %% [markdown]
# #### 3. Gráfico de *candlestick*
# 1. Selecione o período dos últimos 60 dias (corridos) para um dos ativos da sua base
# 2. Monte um gráfico de *candlestick* para esses dados.

# %%
yf_data
# Out:
# Price       Adj Close                          Close                        \
# Ticker       ABEV3.SA   PETR4.SA   VALE3.SA ABEV3.SA   PETR4.SA   VALE3.SA
# Date
# 2023-03-27  13.238050  17.910372  72.258240    13.93  23.180000  78.540001
# 2023-03-28  13.865265  18.227163  73.021858    14.59  23.590000  79.370003
# 2023-03-29  14.074337  18.466690  74.070679    14.81  23.900000  80.510002
# 2023-03-30  14.083839  18.520775  75.275909    14.82  23.969999  81.820000
# 2023-03-31  13.618179  18.118990  73.868279    14.33  23.450001  80.290001
# ...               ...        ...        ...      ...        ...        ...
# 2024-03-18  12.630000  36.340000  60.900002    12.63  36.340000  60.900002
# 2024-03-19  12.540000  36.070000  61.400002    12.54  36.070000  61.400002
# 2024-03-20  12.540000  36.700001  61.810001    12.54  36.700001  61.810001
# 2024-03-21  12.610000  35.700001  61.660000    12.61  35.700001  61.660000
# ...

# %%
lista_indicadores = ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']
ativo = ['PETR4.SA']*len(lista_indicadores)
colunas = list(zip(lista_indicadores, ativo))
petr = yf_data.loc['01/25/2024':,colunas]
petr.columns = lista_indicadores

# %%
from plotly import graph_objects
from plotly.graph_objs import Layout

graph = {
    'x': petr.index,
    'open': petr.Open,
    'close': petr.Close,
    'high': petr.High,
    'low': petr.Low,
    'type': 'candlestick',
    'name': 'PETR4.SA',
    'showlegend': True
}

layout = Layout(
    paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)'
)

grafico = graph_objects.Figure(
    data = [graph],
    layout_title="Índice PETROBRAS",
    layout=layout
)
grafico.update_xaxes(showgrid=True, gridwidth=1, gridcolor='LightGrey')
grafico.update_yaxes(showgrid=True, gridwidth=1, gridcolor='LightGrey')

grafico
# Out:
# <div>                            <div id="1eca4ec7-5011-413a-9e52-b2ca27436d19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1eca4ec7-5011-413a-9e52-b2ca27436d19")) {                    Plotly.newPlot(                        "1eca4ec7-5011-413a-9e52-b2ca27436d19",                        [{"close":[39.279998779296875,39.959999084472656,40.56999969482422,40.31999969482422,40.7599983215332,41.56999969482422,41.029998779296875,41.209999084472656,41.59000015258789,42.20000076293945,41.86000061035156,41.29999923706055,40.9900016784668,42.29999923706055,42.689998626708984,42.900001525878906,42.45000076293945,42.5099983215332,42.189998626708984,41.900001525878906,42.689998626708984,42.630001068115234,40.43000030517578,40.13999938964844,40.18000030517578,
# ...
